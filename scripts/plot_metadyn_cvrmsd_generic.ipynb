# %%
import os
import seaborn as sns
import pandas as pd
import numpy as np
import pandas as pd
from functools import reduce
import matplotlib.pyplot as plt

# %%
df1 = pd.read_table("<path_to_cv_rmsd_file>", sep=',')

# %%
df1= df1.set_index('Pose/Time (ns)')

# %%
df1
# Out:
#                 ZINC000100299612: PersScore 0.024 PoseScore 3.319 DockingScore -9.735  \
# Pose/Time (ns)
# 0.000                                                9.460000e-09
# 0.001                                                2.404023e-01
# 0.002                                                2.795626e-01
# 0.003                                                3.346051e-01
# 0.004                                                3.583656e-01
# ...                                                           ...
# 9.996                                                3.411412e+00
# 9.997                                                3.411371e+00
# 9.998                                                3.411335e+00
# 9.999                                                3.411309e+00
# 10.000                                               3.411238e+00
#
#                 GTP: PersScore 0.214 PoseScore 1.633 DockingScore -15.753  \
# Pose/Time (ns)
# ...

# %%
sns.set(style="darkgrid")
from matplotlib import pyplot

# %%
from matplotlib import pyplot
import matplotlib.ticker as ticker

a4_dims = (10.3, 5.8)
fig, ax = pyplot.subplots(figsize=a4_dims)

with sns.plotting_context("notebook",font_scale=1.2):
    g = sns.lineplot(data=df1, palette="bright", linewidth=2.5, ci="sd",dashes=False)
    
g.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
g.set_xlabel("Time (ns)",fontsize=15)
g.set_ylabel("CV RMSD (A)",fontsize=15)
#g.set_title('ZINC000003932191', fontsize=20)
g.tick_params(labelsize=15)
